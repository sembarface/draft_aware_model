# %%
import pandas as pd

# %%
df = pd.read_parquet("data/patch_60/ml/draft_candidates_pick.parquet")

print(df.shape)
print(df["target"].value_counts())
print(df.groupby("state_id")["target"].sum().value_counts())
print(df.groupby("state_id").size().describe())
df.groupby("state_id")["target"].sum()
# Out:
# (386320, 24)
# target
# 0    382880
# 1      3440
# Name: count, dtype: int64
# target
# 1    3440
# Name: count, dtype: int64
# count    3440.000000
# mean      112.302326
# std         4.940753
# min       104.000000
# 25%       110.000000
# 50%       113.000000
# 75%       115.000000
# max       120.000000
# dtype: float64
# state_id
# 8744395141_13    1
# 8744395141_14    1
# 8744395141_15    1
# 8744395141_16    1
# 8744395141_17    1
#                 ..
# 8784597508_18    1
# 8784597508_23    1
# 8784597508_24    1
# 8784597508_8     1
# 8784597508_9     1
# Name: target, Length: 3440, dtype: int64
